# %%
def bmi(weight, height):
    if weight < 20  or weight > 200 or \
       height < 1.0 or height > 2.5:
        return None
    return weight / height ** 2

# %%
print(bmi(150, 1.65))   # indice de masa corporal
# Out:
# 55.096418732782375

# %%
import os
print("Partida: ", os.getcwd())      # Saber de donde partimos
# Out:
# Partida:  g:\Mi unidad\home\core\code\ds\src\u1
